# %% [markdown]
# ## Python- Pandas
#
# Pandas is an open-source package for data analysis in Python. It is built on the numpy library and written in languages like Python, Cython, and C. In pandas, we can import data from various file formats like JSON, SQL, Microsoft Excel, etc.
#
# Exploring data using pandas is the most basic skill needed for any data analysis using python. Let's go through all the necessary methods and functions in panda. I am only going through the uses in a tabulated data.
#
# Every module need to be imported.

# %%
import pandas as pd

# %% [markdown]
# # Reading data
#
# To read any data file, and store the contents of that file into a variable called data we use the pandas.read_csv() function:
#
# read_csv() is used to read a comma-separated values(csv) file into DataFrame.

# %%
fp = r'C:\Users\Gokul G\Desktop\WORK\GISISH\GIS-ish\data\Kanpur.csv'
data = pd.read_csv(fp,sep=',',index_col= None, skiprows=6, na_values=[-999.0,-999])

# %%
data.head()
# Out:
#       Month  AOD_1640nm  AOD_1020nm  AOD_870nm  AOD_865nm  AOD_779nm  \
# 0  2001-JAN         NaN    0.176252   0.224173        NaN        NaN
# 1  2001-FEB         NaN    0.207033   0.249738        NaN        NaN
# 2  2001-MAR         NaN    0.222493   0.249700        NaN        NaN
# 3  2001-APR         NaN    0.317698   0.338976        NaN        NaN
# 4  2001-MAY         NaN    0.671964   0.702189        NaN        NaN
#
#    AOD_675nm  AOD_667nm  AOD_620nm  AOD_560nm  ...  \
# 0   0.313830        NaN        NaN        NaN  ...
# 1   0.327059        NaN        NaN        NaN  ...
# 2   0.294628        NaN        NaN        NaN  ...
# 3   0.373772        NaN        NaN        NaN  ...
# 4   0.752185        NaN        NaN        NaN  ...
#
#    NUM_POINTS[440-870_Angstrom_Exponent]  \
# 0                                    174
# 1                                    988
# 2                                   1169
# 3                                   1207
# ...

# %%
data.describe()
# Out:
#        AOD_1640nm  AOD_1020nm   AOD_870nm  AOD_865nm  AOD_779nm   AOD_675nm  \
# count  113.000000  225.000000  228.000000        0.0        0.0  231.000000
# mean     0.214897    0.335258    0.386183        NaN        NaN    0.493446
# std      0.104191    0.136913    0.134328        NaN        NaN    0.146812
# min      0.069623    0.128439    0.155948        NaN        NaN    0.091856
# 25%      0.149434    0.244783    0.291455        NaN        NaN    0.386120
# 50%      0.172581    0.307655    0.370896        NaN        NaN    0.479536
# 75%      0.271055    0.386865    0.450169        NaN        NaN    0.587685
# max      0.591585    0.991452    1.013257        NaN        NaN    1.049267
#
#        AOD_667nm  AOD_620nm  AOD_560nm  AOD_555nm  ...  \
# count        0.0        0.0        0.0        0.0  ...
# mean         NaN        NaN        NaN        NaN  ...
# std          NaN        NaN        NaN        NaN  ...
# min          NaN        NaN        NaN        NaN  ...
# ...

# %%
cols = data.columns[data.isnull().mean()>0.5]


data1= data.drop(cols, axis=1)

# %%
data1.describe()
# Out:
#        AOD_1020nm   AOD_870nm   AOD_675nm   AOD_500nm   AOD_440nm   AOD_380nm  \
# count  225.000000  228.000000  231.000000  231.000000  231.000000  228.000000
# mean     0.335258    0.386183    0.493446    0.663366    0.737413    0.827270
# std      0.136913    0.134328    0.146812    0.180585    0.198788    0.216097
# min      0.128439    0.155948    0.091856    0.306863    0.338676    0.404804
# 25%      0.244783    0.291455    0.386120    0.527648    0.587554    0.670690
# 50%      0.307655    0.370896    0.479536    0.632836    0.711554    0.798324
# 75%      0.386865    0.450169    0.587685    0.781024    0.875255    0.978104
# max      0.991452    1.013257    1.049267    1.125929    1.246422    1.371127
#
#         AOD_340nm  Precipitable_Water(cm)  440-870_Angstrom_Exponent  \
# count  230.000000              230.000000                 231.000000
# mean     0.892741                2.718355                   1.023243
# ...
